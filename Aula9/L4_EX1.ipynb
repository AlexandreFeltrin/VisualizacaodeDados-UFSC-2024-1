# %%
import pandas as pd
import numpy as np

# %%
LgData= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/programming language trend over time.csv')

LgData
# Out:
#           Week  Python  Java  C++
# 0    4/21/2019      55    55   18
# 1    4/28/2019      52    50   16
# 2     5/5/2019      56    56   17
# 3    5/12/2019      56    61   18
# 4    5/19/2019      57    56   17
# ..         ...     ...   ...  ...
# 257  3/24/2024      79    47   19
# 258  3/31/2024      81    51   19
# 259   4/7/2024      77    45   18
# 260  4/14/2024      78    48   19
# 261  4/21/2024      71    42   17
#
# [262 rows x 4 columns]

# %%
LgData.head()
# Out:
#         Week  Python  Java  C++
# 0  4/21/2019      55    55   18
# 1  4/28/2019      52    50   16
# 2   5/5/2019      56    56   17
# 3  5/12/2019      56    61   18
# 4  5/19/2019      57    56   17

# %%
LgData['Python'].mean()
# Out:
# 68.96564885496183

# %%
LgData['Java'].mean()
# Out:
# 48.85114503816794

# %%
LgData['C++'].mean()
# Out:
# 19.290076335877863
