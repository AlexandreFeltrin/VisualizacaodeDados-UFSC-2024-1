# %%
import pandas as pd
import numpy as np

# %%
dados = {
  "ano":[2014,2011,2012,2011,2012,2013],
  "estado":["PR","SC","RS","RJ","MG","SP"],
  "desempenho":[1.5,10.0,3.6,2.4,2.9,3.2]
}

df=pd.DataFrame(dados)


df
# Out:
#     ano estado  desempenho
# 0  2014     PR         1.5
# 1  2011     SC        10.0
# 2  2012     RS         3.6
# 3  2011     RJ         2.4
# 4  2012     MG         2.9
# 5  2013     SP         3.2

# %%
novaLinha = pd.DataFrame({
  "ano":[2015,2019,2017,2018,2022,2023],
  "estado":["AC","CE","PE","RR","GO","SE"],
  "desempenho":[1.9,8.0,5.6,5.4,2.9,3.2]
})

df=pd.concat([df,novaLinha],ignore_index=True)
df
# Out:
#      ano estado  desempenho
# 0   2014     PR         1.5
# 1   2011     SC        10.0
# 2   2012     RS         3.6
# 3   2011     RJ         2.4
# 4   2012     MG         2.9
# 5   2013     SP         3.2
# 6   2015     AC         1.9
# 7   2019     CE         8.0
# 8   2017     PE         5.6
# 9   2018     RR         5.4
# 10  2022     GO         2.9
# 11  2023     SE         3.2

# %%
df=df.drop(index=5)
df
# Out:
#      ano estado  desempenho
# 0   2014     PR         1.5
# 1   2011     SC        10.0
# 2   2012     RS         3.6
# 3   2011     RJ         2.4
# 4   2012     MG         2.9
# 6   2015     AC         1.9
# 7   2019     CE         8.0
# 8   2017     PE         5.6
# 9   2018     RR         5.4
# 10  2022     GO         2.9
# 11  2023     SE         3.2

# %%
df["Divida"]=1000,2945,3000,123430,2020,94394,9494393,74374,388484,328448,309404

df
# Out:
#      ano estado  desempenho   Cidade   Divida
# 0   2014     PR         1.5     1000     1000
# 1   2011     SC        10.0     2945     2945
# 2   2012     RS         3.6     3000     3000
# 3   2011     RJ         2.4   123430   123430
# 4   2012     MG         2.9     2020     2020
# 6   2015     AC         1.9    94394    94394
# 7   2019     CE         8.0  9494393  9494393
# 8   2017     PE         5.6    74374    74374
# 9   2018     RR         5.4   388484   388484
# 10  2022     GO         2.9   328448   328448
# 11  2023     SE         3.2   309404   309404

# %%
filtro=df.loc[df["Divida"]>5000]

filtro
# Out:
#      ano estado  desempenho   Cidade   Divida
# 3   2011     RJ         2.4   123430   123430
# 6   2015     AC         1.9    94394    94394
# 7   2019     CE         8.0  9494393  9494393
# 8   2017     PE         5.6    74374    74374
# 9   2018     RR         5.4   388484   388484
# 10  2022     GO         2.9   328448   328448
# 11  2023     SE         3.2   309404   309404
