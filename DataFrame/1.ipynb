# %%
import pandas as pd
import numpy as np
# Out:
# Falha ao iniciar o Kernel.
#
# Bad file descriptor (C:\Users\runneradmin\AppData\Local\Temp\tmp9czwcdbh\build\_deps\bundled_libzmq-src\src\epoll.cpp:73).
#
# Consulte o <a href='command:jupyter.viewOutput'>log</a> do Jupyter para obter mais detalhes.

# %%
dados={"id":np.arange(0,len(dados['nome'])),
      "data_Nascimento":["01/01/01","01/02/20","08/07/04","24/05/10","04/11/99","11/02/03","14/08/02","01/02/11","01/03/88","02/07/99"],
       "cpf":["98098904990","8476048480","808439704","454098590","5017480685","5446077096","4664156461","0979046565","5874084840","850880540"],
       "nome":["João","Maria","Laura","Bruna","Julia","Gabriela","Rafaela","Lara","Nicole","Mario"]}

df=pd.DataFrame(dados)

df
# Out:
#    id data_Nascimento          cpf      nome
# 0   0        01/01/01  98098904990      João
# 1   1        01/02/20   8476048480     Maria
# 2   2        08/07/04    808439704     Laura
# 3   3        24/05/10    454098590     Bruna
# 4   4        04/11/99   5017480685     Julia
# 5   5        11/02/03   5446077096  Gabriela
# 6   6        14/08/02   4664156461   Rafaela
# 7   7        01/02/11   0979046565      Lara
# 8   8        01/03/88   5874084840    Nicole
# 9   9        02/07/99    850880540     Mario

# %%
df=df.drop(index=5)
df
# Out:
#    id data_Nascimento          cpf     nome Cidade
# 0   0        01/01/01  98098904990     João  Turvo
# 1   1        01/02/20   8476048480    Maria  Turvo
# 2   2        08/07/04    808439704    Laura  Turvo
# 3   3        24/05/10    454098590    Bruna  Turvo
# 4   4        04/11/99   5017480685    Julia  Turvo
# 6   6        14/08/02   4664156461  Rafaela  Turvo
# 7   7        01/02/11   0979046565     Lara  Turvo
# 8   8        01/03/88   5874084840   Nicole  Turvo
# 9   9        02/07/99    850880540    Mario  Turvo

# %%
df["Cidade"]="Turvo","Turvo","Turvo","Turvo","Turvo","Turvo","Turvo","Turvo","Turvo"

df
# Out:
#    id data_Nascimento          cpf     nome Cidade
# 0   0        01/01/01  98098904990     João  Turvo
# 1   1        01/02/20   8476048480    Maria  Turvo
# 2   2        08/07/04    808439704    Laura  Turvo
# 3   3        24/05/10    454098590    Bruna  Turvo
# 4   4        04/11/99   5017480685    Julia  Turvo
# 6   6        14/08/02   4664156461  Rafaela  Turvo
# 7   7        01/02/11   0979046565     Lara  Turvo
# 8   8        01/03/88   5874084840   Nicole  Turvo
# 9   9        02/07/99    850880540    Mario  Turvo

# %%
filtro_df=df.loc[df['id']>6]

filtro_df
# Out:
#    id data_Nascimento         cpf    nome Cidade
# 7   7        01/02/11  0979046565    Lara  Turvo
# 8   8        01/03/88  5874084840  Nicole  Turvo
# 9   9        02/07/99   850880540   Mario  Turvo
