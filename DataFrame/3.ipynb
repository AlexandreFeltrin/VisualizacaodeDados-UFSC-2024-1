# %%
import pandas as pd
import numpy as np

# %%
dadosVendas={'Produto': ['Smartphone', 'Notebook', 'Fone de Ouvido', 'Tablet', 'Câmera Digital',
                'Smartwatch', 'Impressora', 'Teclado', 'Mouse', 'Carregador Portátil',
                'Monitor', 'Caixa de Som', 'HD Externo', 'Pen Drive', 'Roteador',
                'Cabo USB', 'Hub USB', 'Adaptador HDMI', 'Webcam', 'Mochila'],
    "Quantidade": [10, 15, 20, 25, 30,
                   10, 15, 20, 25, 30,
                   10, 15, 20, 25, 30,
                   10, 15, 20, 25, 30],
    "Preço": [1000, 1500, 200, 500, 400,
              300, 200, 50, 30, 80,
              200, 100, 150, 20, 120,
              10, 15, 25, 50, 70],
    "Data":["01/03/2024","31/01/2024","05/04/2024","22/03/2024","01/03/2024","01/03/2024","24/02/2023","01/03/2024","01/03/2024","01/03/2024","21/03/2024","01/03/2024","25/08/2023",
            "23/03/2024","01/03/2024","01/06/2023","01/03/2024","06/02/2023","01/03/2024","20/02/2023"]
             }

dfVendas=pd.DataFrame(dadosVendas)

dfVendas
# Out:
#                 Produto  Quantidade  Preço        Data
# 0            Smartphone          10   1000  01/03/2024
# 1              Notebook          15   1500  31/01/2024
# 2        Fone de Ouvido          20    200  05/04/2024
# 3                Tablet          25    500  22/03/2024
# 4        Câmera Digital          30    400  01/03/2024
# 5            Smartwatch          10    300  01/03/2024
# 6            Impressora          15    200  24/02/2023
# 7               Teclado          20     50  01/03/2024
# 8                 Mouse          25     30  01/03/2024
# 9   Carregador Portátil          30     80  01/03/2024
# 10              Monitor          10    200  21/03/2024
# 11         Caixa de Som          15    100  01/03/2024
# 12           HD Externo          20    150  25/08/2023
# 13            Pen Drive          25     20  23/03/2024
# 14             Roteador          30    120  01/03/2024
# 15             Cabo USB          10     10  01/06/2023
# ...

# %%
df01032024=dfVendas.loc[dfVendas['Data']=="01/03/2024"]

df01032024
# Out:
#                 Produto  Quantidade  Preço        Data
# 0            Smartphone          10   1000  01/03/2024
# 4        Câmera Digital          30    400  01/03/2024
# 5            Smartwatch          10    300  01/03/2024
# 7               Teclado          20     50  01/03/2024
# 8                 Mouse          25     30  01/03/2024
# 9   Carregador Portátil          30     80  01/03/2024
# 11         Caixa de Som          15    100  01/03/2024
# 14             Roteador          30    120  01/03/2024
# 16              Hub USB          15     15  01/03/2024
# 18               Webcam          25     50  01/03/2024
